# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %%
# Exercise 2: Create a markdown cell with title of the notebook

# Import necessary libraries
import matplotlib.pyplot as plt

# Create a Jupyter notebook and add a markdown cell with the title
fig, ax = plt.subplots(figsize=(8, 2))
ax.text(0.5, 0.5, 'Data Science Tools and Ecosystem', ha='center', va='center', fontsize=18)
ax.axis('off')

# Save the figure as 2-title.png
plt.savefig('2-title.png', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
# Exercise 3: Create a markdown cell for an introduction

# Create a Jupyter notebook and add a markdown cell for introduction
fig, ax = plt.subplots(figsize=(8, 2))
ax.text(0.5, 0.5, "In this notebook, Data Science Tools and Ecosystem are summarized.", ha='center', va='center', fontsize=12)
ax.axis('off')

# Save the figure as 3-intro.png
plt.savefig('3-intro.png', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
# Exercise 4: Create a markdown cell to list data science languages

# Create a Jupyter notebook and add a markdown cell for data science languages
fig, ax = plt.subplots(figsize=(8, 3))
ax.text(0.1, 0.5, "Some of the popular languages that Data Scientists use are:", fontsize=12)
ax.text(0.1, 0.3, "1. Python", fontsize=12)
ax.text(0.1, 0.2, "2. R", fontsize=12)
ax.text(0.1, 0.1, "3. JAVA", fontsize=12)
ax.axis('off')

# Save the figure as 4-dslanguages.png
plt.savefig('4-dslanguages.png', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
# Exercise 5: Create a markdown cell to list data science libraries

# Create a Jupyter notebook and add a markdown cell for data science libraries
fig, ax = plt.subplots(figsize=(8, 3))
ax.text(0.1, 0.5, "Some of the commonly used libraries used by Data Scientists include:", fontsize=12)
ax.text(0.1, 0.3, "1. NumPy", fontsize=12)
ax.text(0.1, 0.2, "2. Pandas", fontsize=12)
ax.text(0.1, 0.1, "3. Scikit-Learn", fontsize=12)
ax.axis('off')

# Save the figure as 5-dslibraries.png
plt.savefig('5-dslibraries.png', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
# Exercise 6: Create a markdown cell with a table of Data Science tools

# Create a Jupyter notebook and add a markdown cell for Data Science tools table
fig, ax = plt.subplots(figsize=(8, 2))
table_data = [['Data Science Tools'], ['Tool 1'], ['Tool 2'], ['Tool 3']]
ax.table(cellText=table_data, cellLoc='center', loc='center')
ax.axis('off')

# Save the figure as 6-dstools.png
plt.savefig('6-dstools.png', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
# Exercise 7: Create a markdown cell introducing arithmetic expression examples

# Create a Jupyter notebook and add a markdown cell for arithmetic expression examples
fig, ax = plt.subplots(figsize=(8, 2))
ax.text(0.1, 0.5, "### Below are a few examples of evaluating arithmetic expressions in Python.", fontsize=12)
ax.axis('off')

# Save the figure as 7-introarithmetic.png
plt.savefig('7-introarithmetic.png', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
# Exercise 8: Create a code cell to multiply and add numbers

# Create a Jupyter notebook and add a code cell for multiplying and adding numbers
(3*4)+5
# Out:
# 17

# %%
#This will convert 200 minutes to hours by diving by 60
minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335

# %%
# Exercise 10: Insert a markdown cell to list Objectives

# Create a Jupyter notebook and insert a markdown cell to list objectives
fig, ax = plt.subplots(figsize=(8, 3))
ax.text(0.1, 0.5, "**Objectives:**", fontsize=12, fontweight='bold')
ax.text(0.1, 0.3, "- List popular languages for Data Science", fontsize=12)
ax.text(0.1, 0.2, "- Getting Started with Jupyter", fontsize=12)
ax.text(0.1, 0.1, "- Introduce common libraries used by Data Scientists", fontsize=12)
ax.axis('off')

# Save the figure as 10-objectives.png
plt.savefig('10-objectives.png', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
## Author
fig, ax = plt.subplots(figsize=(3, 3))
ax.text(0.1, 0.2, "Author:", fontsize=16)
ax.text(0.1, 0.1, "Sajeed Khan", fontsize=12)
ax.axis('off')

plt.savefig('11-authordetails.png', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
# Out:
#   File "/tmp/ipykernel_981/3597759095.py", line 1
#     echo "# Coursera-P2P" >> README.md
#                         ^
# SyntaxError: invalid syntax
